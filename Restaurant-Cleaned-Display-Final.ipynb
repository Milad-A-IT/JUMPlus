# %%
import pandas as pd
#import numpy as nm
import matplotlib.pyplot as plt
import csv
import cx_Oracle

# %%
#6: S3 Endpoint to access the CSV file*** https://projectresturant.s3.amazonaws.com/independence100(cleaned).csv ***

# %%
#7b

#How to install cx_oracle modules from anaconda prompt : => conda install -c anaconda cx_oracle <= 
connection = cx_Oracle.connect("resturant","123","//localhost:1521/ORCLPDB")
query = "select * from Project_res"  #create query
df_ora = pd.read_sql(query, con=connection) #read the query from Qracle db
df_ora
# Out:
#     RANK                           RESTAURANT       SALES  AVERAGE_CHECK  \
# 0      1             Carmine's (Times Square)  39080335.0           40.0
# 1      2                The Boathouse Orlando  35218364.0           43.0
# 2      3                     Old Ebbitt Grill  29104017.0           33.0
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0           90.0
# 4      5             Bryant Park Grill & Cafe  26900000.0           62.0
# ..   ...                                  ...         ...            ...
# 90    95           Franciscan Crab Restaurant  12218147.0           59.0
# 91    96                 George's at the Cove  12194000.0           80.0
# 92    97                            Le Coucou  12187523.0           95.0
# 93    98                              Mi Vida  12032014.0           38.0
# 94    99                               Upland  11965564.0           52.0
#
#              CITY   STATE  MEALS_SERVED
# 0        New York    N.Y.      469803.0
# ...

# %%
#7A
path = ("C:\\Users\Milad\Desktop\jump program\Data Analyst-Capitalone\Python\Project\Project_res.csv")

# %%
df = pd.read_csv(path)
df
# Out:
#     RANK                           RESTAURANT     SALES  AVERAGE_CHECK  \
# 0      1             Carmine's (Times Square)  39080335             40
# 1      2                The Boathouse Orlando  35218364             43
# 2      3                     Old Ebbitt Grill  29104017             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180             90
# 4      5             Bryant Park Grill & Cafe  26900000             62
# ..   ...                                  ...       ...            ...
# 90    95           Franciscan Crab Restaurant  12218147             59
# 91    96                 George's at the Cove  12194000             80
# 92    97                            Le Coucou  12187523             95
# 93    98                              Mi Vida  12032014             38
# 94    99                               Upland  11965564             52
#
#              CITY   STATE  MEALS_SERVED
# 0        New York    N.Y.        469803
# ...

# %%
#Total Meals Served 
total_MS = df['MEALS_SERVED'].sum()
total_MS
# Out:
# 30441027

# %%
# Average Meals Served
avg_MS = df['MEALS_SERVED'].mean()
avg_MS
# Out:
# 320431.86315789475

# %%
#Total Sales 
total_Sales = df['SALES'].sum()
total_Sales
# Out:
# 1687795880

# %%
#Average Sales
avg_sales = df['SALES'].mean()
avg_sales
# Out:
# 17766272.42105263

# %%
#Total Average Check 
total_avgCheck = df['AVERAGE_CHECK'].sum()
total_avgCheck
# Out:
# 6546

# %%
#Average Sales
avg_avgCheck = df['AVERAGE_CHECK'].mean()
avg_avgCheck
# Out:
# 68.90526315789474

# %%
bar_x = df.RESTAURANT
bar_y = df.AVERAGE_CHECK
plt.barh(bar_x, bar_y)
fig = plt.gcf()
fig.set_size_inches(20, 20)
fig.savefig('average_check.png', dpi=250)

# %%
plt.xticks(rotation = 90)
scatter_x = df.RANK
scatter_y = df.MEALS_SERVED
plt.scatter(scatter_x, scatter_y)
fig = plt.gcf()
fig.set_size_inches(20, 20)
fig.savefig('scatter_Meals_Served.png', dpi=250)

# %%
Pie_label = df.RESTAURANT
Pie_Size = df.SALES
explode = (0, 0, 0, 0)  # only "explode" the 2nd slice (i.e. 'Hogs')

fig1, ax1 = plt.subplots()
ax1.pie(Pie_Size, labels=Pie_label, autopct='%1.1f%%',
        shadow=True, startangle=0)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

ax4 = fig.add_subplot()
ax4.set_title('Pie Chart of Restaurant Sales for 2020')

fig = plt.gcf()
fig.set_size_inches(20, 20)
fig.savefig('Sales_Pie.png', dpi=250)
# Out:
# <ipython-input-14-253f2e2eba7b>:10: MatplotlibDeprecationWarning: Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   ax4 = fig.add_subplot()
