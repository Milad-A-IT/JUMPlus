# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %%
path = "C:\\Users\Milad\Desktop\jump program\Data Analyst-Capitalone\Python\Project\independence100.csv"

# %%
df = pd.read_csv(path)
df
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
# 99   100               Virgil's Real Barbecue  11391678.0             27
#
#           City   State  Meals Served
# 0     New York    N.Y.      469803.0
# ...

# %%
clean_df = df.dropna(subset = ["Average Check","Meals Served","Sales"])
clean_df = clean_df.loc[(clean_df['Sales'] > 0)&(clean_df['Average Check']>0)&(clean_df['Meals Served']>0)]
clean_df
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
# 99   100               Virgil's Real Barbecue  11391678.0             27
#
#           City   State  Meals Served
# 0     New York    N.Y.      469803.0
# ...

# %%
Total_Ms = clean_df['Meals Served'].sum()
Total_Ms
# Out:
# 31716666.0

# %%
Avg_MS = clean_df['Meals Served'].mean()
Avg_MS
# Out:
# 317166.66

# %%
total_Sales = clean_df['Sales'].sum()
total_Sales
# Out:
# 1783343432.0

# %%
avg_Sales = clean_df['Sales'].mean()
avg_Sales
# Out:
# 17833434.32

# %%
total_avgcheck = clean_df['Average Check'].sum()
total_avgcheck
# Out:
# 6905

# %%
ave_avgcheck = clean_df['Average Check'].mean()
ave_avgcheck
# Out:
# 69.05

# %%
df_cleaned = df.drop_duplicates(subset=['Restaurant'])
df_cleaned
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 94    95           Franciscan Crab Restaurant  12218147.0             59
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
#
#              City   State  Meals Served
# 0        New York    N.Y.      469803.0
# ...

# %%
df_comp = clean_df.drop_duplicates(subset=['Restaurant'])
df_comp
# Out:
#     Rank                           Restaurant       Sales  Average Check  \
# 0      1             Carmine's (Times Square)  39080335.0             40
# 1      2                The Boathouse Orlando  35218364.0             43
# 2      3                     Old Ebbitt Grill  29104017.0             33
# 3      4  LAVO Italian Restaurant & Nightclub  26916180.0             90
# 4      5             Bryant Park Grill & Cafe  26900000.0             62
# ..   ...                                  ...         ...            ...
# 94    95           Franciscan Crab Restaurant  12218147.0             59
# 95    96                 George's at the Cove  12194000.0             80
# 96    97                            Le Coucou  12187523.0             95
# 97    98                              Mi Vida  12032014.0             38
# 98    99                               Upland  11965564.0             52
#
#              City   State  Meals Served
# 0        New York    N.Y.      469803.0
# ...

# %%
#export CSV
df_comp.to_csv("C:\\Users\Milad\Desktop\jump program\Data Analyst-Capitalone\Python\Project\independence100(cleaned).csv")
